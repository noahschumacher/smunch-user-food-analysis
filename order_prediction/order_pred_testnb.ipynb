# %%
## Initialization and imports
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt

## sklearn models and validation
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestRegressor

## Changing directory to top folder (All programs run from top)
import os
os.chdir('/Users/nschumacher/docs/galvanize/smunch-user-food-analysis')

## local run sql file
from db.python_db import connect, run_sql_query
from run2.models.user_class import User


# %matplotlib inline  
# %config InlineBackend.figure_format='retina'

## Set random seed
np.random.seed(seed=14)

# %%
conn = connect()

# %%
##List of top 20 ordering customers
top_20 = ['0030N00002LQq9ZQAT', '0030N00002LQqjPQAT', '0030N00002LQpX3QAL',
       '0030N00002LQpucQAD', '0030N00002LQqNIQA1', '0030N00002LQqAGQA1',
       '0030N00002LQp6XQAT', '0030N00002LQqcbQAD', '0030N00002LQq9lQAD',
       '0030N00002LQpubQAD', '0030N00002LQptWQAT', '0030N00002LQpO3QAL',
       '0030N00002LQq9gQAD', '0030N00002LQq9dQAD', '0030N00002LQq9cQAD',
       '0030N00002LQqvkQAD', '0030N00002LQpwoQAD', '0030N00002LQptYQAT',
       '0030N00002LQpN2QAL', '0030N00002LQptaQAD']
run_sql_query("SELECT DISTINCT(account_sfid_order) FROM bi.executed_order_employee WHERE contact_sfid=%s")

# %%
# ## Building user object dictionary
# users = {}
# for i in top_20:
#     u = User(i, conn)
#     u.build_table()
#     users[i] = u
#     print(i, "done.")

user_id = '0030N00002LQqB9QAL'
account_id = '0010N00004IaGG6QAN'
u = User(user_id, account_id, conn)
u.build_table()
# Out:
#                meal_id  meal_count  \
# 0   a050N00000zZg5KQAS           1
# 1   a050N00000zZfzCQAS           1
# 2   a050N00000zZfyUQAS           2
# 3   a050N000010W5ezQAC           1
# 4   a050N00000zZg8NQAS           2
# 5   a050N00000zZg5EQAS           3
# 6   a050N00000zZgH3QAK           3
# 7   a050N00000zZg8AQAS           8
# 8   a050N000010W5f9QAC           1
# 9   a050N00000za4nqQAA           7
# 10  a050N000010XhDBQA0           1
# 11  a050N000010W5f8QAC           1
# 12  a050N00000zZgFTQA0           1
# 13  a050N00000zZg5LQAS           2
# 14  a050N00000zbGGHQA2           1
# 15  a050N00000zbGCDQA2           1
# 16  a050N00000zZg63QAC           5
# 17  a050N00000zZfz2QAC           1
# 18  a050N00000zZfysQAC           2
# 19  a050N00000zZg0HQAS           2
# 20  a050N00000zZg0ZQAS           2
# 21  a050N00000zZg44QAC           1
# 22  a050N000010W5fIQAS           1
# 23  a050N00000zZg0XQAS           3
# 24  a050N00000zZg4XQAS           3
# 25  a050N00000zZfyyQAC           2
# 26  a050N00000zZg8lQAC           2
# 27  a050N00000zZg4mQAC           2
# 28  a050N00000zZg8DQAS           1
# 29  a050N00000zZg4QQAS           1
# ..                 ...         ...
# 60  a050N000010YKzlQAG           1
# 61  a050N00000zbES4QAM           1
# 62  a050N00000zZfz5QAC           2
# 63  a050N00000zZfz3QAC           1
# 64  a050N00000zZg3YQAS           1
# 65  a050N00000zZg65QAC           3
# 66  a050N00000zZg4RQAS           2
# 67  a050N000010X2aDQAS           1
# 68  a050N0000150ewBQAQ           1
# 69  a050N00000zZg0YQAS           2
# 70  a050N00000zZg4aQAC           2
# 71  a050N000010X2ZeQAK           1
# 72  a050N000010X9i6QAC           2
# 73  a050N00000zbFdeQAE           1
# 74  a050N000010YKy8QAG           1
# 75  a050N00000zZg5SQAS           1
# 76  a050N00000zZg58QAC           2
# 77  a050N000010XhClQAK           1
# 78  a050N00000zZg8XQAS           2
# 79  a050N000010XNiZQAW           1
# 80  a050N00000zZfyTQAS           3
# 81  a050N00000zZg4TQAS           1
# 82  a050N00000zZg64QAC           2
# 83  a050N00000zZfzeQAC           1
# 84  a050N00000zZg4SQAS           1
# 85  a050N00000zbESJQA2           3
# 86  a050N00000zZg8WQAS           2
# 87  a050N000013v74gQAA           1
# 88  a050N000010XhCMQA0           1
# 89  a050N00000zbFdjQAE           1
#
#                                        ingredient_ids
# 0   [a060N00002XMfaiQAD, a060N00002XMfW9QAL, a060N...
# 1   [a060N00002XMfVwQAL, a060N00002XMfaiQAD, a060N...
# 2   [a060N00002XMfWNQA1, a060N00002XMfWGQA1, a060N...
# 3   [a060N00002XMfWgQAL, a060N00002SBNSFQA5, a060N...
# 4   [a060N00002XMfaiQAD, a060N00002XMfXtQAL, a060N...
# 5   [a060N00002XMfXmQAL, a060N00002XMfaiQAD, a060N...
# 6   [a060N00002XMfUSQA1, a060N00002XMfW7QAL, a060N...
# 7   [a060N00002XMfW7QAL, a060N00002XMfZNQA1, a060N...
# 8   [a060N00002XMfTPQA1, a060N00002XMfe2QAD, a060N...
# 9   [a060N00002XMfWcQAL, a060N00002XMfYIQA1, a060N...
# 10  [a060N00002XMfVcQAL, a060N00002Z7fjqQAB, a060N...
# 11  [a060N00002Z7fpZQAR, a060N00002Z7fpeQAB, a060N...
# 12  [a060N00002XMfW7QAL, a060N00002XMfWNQA1, a060N...
# 13  [a060N00002XMfWhQAL, a060N00002XMfWbQAL, a060N...
# 14  [a060N00002XMfVdQAL, a060N00002XMfWNQA1, a060N...
# 15  [a060N00002XMfZdQAL, a060N00002XMfU2QAL, a060N...
# 16  [a060N00002XMfaiQAD, a060N00002XMfXsQAL, a060N...
# 17  [a060N00002XMfWNQA1, a060N00002XMfaTQAT, a060N...
# 18  [a060N00002XMfYIQA1, a060N00002XMfWoQAL, a060N...
# 19  [a060N00002XMfc0QAD, a060N00002XMfdLQAT, a060N...
# 20  [a060N00002XMfaaQAD, a060N00002XMfUkQAL, a060N...
# 21  [a060N00002XMfYEQA1, a060N00002XMfW7QAL, a060N...
# 22  [a060N00002XMfaaQAD, a060N00002XMfTvQAL, a060N...
# 23  [a060N00002XMfWNQA1, a060N00002XMfW9QAL, a060N...
# 24  [a060N00002XMfX7QAL, a060N00002XMfXEQA1, a060N...
# 25  [a060N00002XMfTnQAL, a060N00002XMfW7QAL, a060N...
# 26  [a060N00002XMfXsQAL, a060N00002XMfW1QAL, a060N...
# 27  [a060N00002XMfaiQAD, a060N00002XMfW9QAL, a060N...
# 28  [a060N00002XMfXgQAL, a060N00002XMfW7QAL, a060N...
# 29  [a060N00002XMfUbQAL, a060N00002XMfYYQA1, a060N...
# ..                                                ...
# 60  [a060N00002XMfYQQA1, a060N00002Zo71YQAR, a060N...
# 61  [a060N00002XMfdsQAD, a060N00002XMfXgQAL, a060N...
# 62  [a060N00002XMfZyQAL, a060N00002XMfU9QAL, a060N...
# 63  [a060N00002XMfYEQA1, a060N00002XMfWNQA1, a060N...
# 64  [a060N00002XMfaiQAD, a060N00002XMfW1QAL, a060N...
# 65  [a060N00002XMfaiQAD, a060N00002XMfaeQAD, a060N...
# 66  [a060N00002XMfTnQAL, a060N00002XMfW7QAL, a060N...
# 67  [a060N00002XMfYLQA1, a060N00002XMfalQAD, a060N...
# 68  [a060N00002grUCBQA2, a060N00002ZmIhDQAV, a060N...
# 69  [a060N00002XMfWNQA1, a060N00002XMfZNQA1, a060N...
# 70  [a060N00002XMfaiQAD, a060N00002XMfWNQA1, a060N...
# 71  [a060N00002XMfa6QAD, a060N00002XMfXjQAL, a060N...
# 72  [a060N00002XMfTXQA1, a060N00002XMfVwQAL, a060N...
# 73  [a060N00002XMfUeQAL, a060N00002XMfWDQA1, a060N...
# 74  [a060N00002XMfZBQA1, a060N00002Zq4QwQAJ, a060N...
# 75  [a060N00002XMfdpQAD, a060N00002XMfVwQAL, a060N...
# 76  [a060N00002XMfXjQAL, a060N00002XMfW7QAL, a060N...
# 77  [a060N00002XMfZBQA1, a060N00002XMfWAQA1, a060N...
# 78  [a060N00002XMfaiQAD, a060N00002XMfW9QAL, a060N...
# 79  [a060N00002ZuTU3QAN, a060N00002Zd3qcQAB, a060N...
# 80  [a060N00002XMfWNQA1, a060N00002XMfahQAD, a060N...
# 81  [a060N00002XMfTnQAL, a060N00002XMfW7QAL, a060N...
# 82  [a060N00002XMfaiQAD, a060N00002XMfW9QAL, a060N...
# 83  [a060N00002XMfWNQA1, a060N00002XMfW7QAL, a060N...
# 84  [a060N00002XMfXsQAL, a060N00002XMfVVQA1, a060N...
# 85  [a060N00002XMfdsQAD, a060N00002Z7gBYQAZ, a060N...
# 86  [a060N00002XMfWgQAL, a060N00002XMfYOQA1, a060N...
# 87  [a060N00002fgI5eQAE, a060N00002Zo4t5QAB, a060N...
# 88  [a060N00002XMfVmQAL, a060N00002XMfUvQAL, a060N...
# 89  [a060N00002XMfVcQAL, a060N00002Z7fjqQAB, a060N...
#
# [90 rows x 3 columns]
#                 meal_id  offered_count
# 0    a050N000010Wjb7QAC              3
# 1    a050N00000zbFdjQAE              3
# 2    a050N000010WsrCQAS              2
# 3    a050N00000zZg4WQAS              2
# 4    a050N000010W5fHQAS              1
# 5    a050N0000150evmQAA              1
# 6    a050N000010WjbAQAS              3
# 7    a050N00000zZg8TQAS              1
# 8    a050N00000zZg42QAC              1
# 9    a050N000010W5f9QAC              2
# 10   a050N00000zZfyyQAC              4
# 11   a050N000013tq3OQAQ              2
# 12   a050N00000zbES4QAM              7
# 13   a050N00000zZfz5QAC              4
# 14   a050N00000zZg68QAC              2
# 15   a050N000010W5eyQAC              6
# 16   a050N00000za4nqQAA              7
# 17   a050N00000zZg5UQAS              1
# 18   a050N00000zZg8lQAC              7
# 19   a050N00000zZg4pQAC              1
# 20   a050N000010XhClQAK              3
# 21   a050N00000zZg8fQAC              2
# 22   a050N00000zZg8XQAS              7
# 23   a050N000010X2a3QAC              1
# 24   a050N00000zZfz3QAC              4
# 25   a050N000010XNiZQAW              1
# 26   a050N00000zZgFWQA0              2
# 27   a050N00000zZg8SQAS              1
# 28   a050N00000zZfz0QAC              4
# 29   a050N000010WMcmQAG              6
# ..                  ...            ...
# 168  a050N00000zZfzGQAS              2
# 169  a050N000010YKy8QAG              2
# 170  a050N00000za4mZQAQ              5
# 171  a050N00000zZg8nQAC              7
# 172  a050N000010WsqoQAC              2
# 173  a050N00000zZg4kQAC              2
# 174  a050N00000zZfzWQAS              1
# 175  a050N00000zZg67QAC              2
# 176  a050N000010YKw0QAG              2
# 177  a050N00000zZg4eQAC              2
# 178  a050N000010XhDLQA0              3
# 179  a050N000010Wjb9QAC              3
# 180  a050N00000zbFdZQAU              4
# 181  a050N000010Wjb8QAC              3
# 182  a050N000010W5f2QAC              2
# 183  a050N00000zZg5BQAS              4
# 184  a050N000010YKzlQAG              1
# 185  a050N00000zZg8AQAS              9
# 186  a050N00000zZg5SQAS              1
# 187  a050N000010X2aNQAS              1
# 188  a050N000010W5f1QAC              2
# 189  a050N000010XhCMQA0              3
# 190  a050N00000zZfyrQAC              5
# 191  a050N00000zZg58QAC              5
# 192  a050N000010XyHYQA0              1
# 193  a050N00000zZg3fQAC              1
# 194  a050N00000zZg4XQAS              6
# 195  a050N00000zZfyzQAC              3
# 196  a050N00000zZg5OQAS              1
# 197  a050N00000zZfywQAC              4
#
# [198 rows x 2 columns]
#                     meal_count  \
# meal_id
# a050N00000zZg5KQAS           1
# a050N00000zZfzCQAS           1
# a050N00000zZfyUQAS           2
# a050N000010W5ezQAC           1
# a050N00000zZg8NQAS           2
# a050N00000zZg5EQAS           3
# a050N00000zZgH3QAK           3
# a050N00000zZg8AQAS           8
# a050N000010W5f9QAC           1
# a050N00000za4nqQAA           7
# a050N000010XhDBQA0           1
# a050N000010W5f8QAC           1
# a050N00000zZgFTQA0           1
# a050N00000zZg5LQAS           2
# a050N00000zbGGHQA2           1
# a050N00000zbGCDQA2           1
# a050N00000zZg63QAC           5
# a050N00000zZfz2QAC           1
# a050N00000zZfysQAC           2
# a050N00000zZg0HQAS           2
# a050N00000zZg0ZQAS           2
# a050N00000zZg44QAC           1
# a050N000010W5fIQAS           1
# a050N00000zZg0XQAS           3
# a050N00000zZg4XQAS           3
# a050N00000zZfyyQAC           2
# a050N00000zZg8lQAC           2
# a050N00000zZg4mQAC           2
# a050N00000zZg8DQAS           1
# a050N00000zZg4QQAS           1
# ...                        ...
# a050N000010YKzlQAG           1
# a050N00000zbES4QAM           1
# a050N00000zZfz5QAC           2
# a050N00000zZfz3QAC           1
# a050N00000zZg3YQAS           1
# a050N00000zZg65QAC           3
# a050N00000zZg4RQAS           2
# a050N000010X2aDQAS           1
# a050N0000150ewBQAQ           1
# a050N00000zZg0YQAS           2
# a050N00000zZg4aQAC           2
# a050N000010X2ZeQAK           1
# a050N000010X9i6QAC           2
# a050N00000zbFdeQAE           1
# a050N000010YKy8QAG           1
# a050N00000zZg5SQAS           1
# a050N00000zZg58QAC           2
# a050N000010XhClQAK           1
# a050N00000zZg8XQAS           2
# a050N000010XNiZQAW           1
# a050N00000zZfyTQAS           3
# a050N00000zZg4TQAS           1
# a050N00000zZg64QAC           2
# a050N00000zZfzeQAC           1
# a050N00000zZg4SQAS           1
# a050N00000zbESJQA2           3
# a050N00000zZg8WQAS           2
# a050N000013v74gQAA           1
# a050N000010XhCMQA0           1
# a050N00000zbFdjQAE           1
#
#                                                        ingredient_ids  \
# meal_id
# a050N00000zZg5KQAS  [a060N00002XMfaiQAD, a060N00002XMfW9QAL, a060N...
# a050N00000zZfzCQAS  [a060N00002XMfVwQAL, a060N00002XMfaiQAD, a060N...
# a050N00000zZfyUQAS  [a060N00002XMfWNQA1, a060N00002XMfWGQA1, a060N...
# a050N000010W5ezQAC  [a060N00002XMfWgQAL, a060N00002SBNSFQA5, a060N...
# a050N00000zZg8NQAS  [a060N00002XMfaiQAD, a060N00002XMfXtQAL, a060N...
# a050N00000zZg5EQAS  [a060N00002XMfXmQAL, a060N00002XMfaiQAD, a060N...
# a050N00000zZgH3QAK  [a060N00002XMfUSQA1, a060N00002XMfW7QAL, a060N...
# a050N00000zZg8AQAS  [a060N00002XMfW7QAL, a060N00002XMfZNQA1, a060N...
# a050N000010W5f9QAC  [a060N00002XMfTPQA1, a060N00002XMfe2QAD, a060N...
# a050N00000za4nqQAA  [a060N00002XMfWcQAL, a060N00002XMfYIQA1, a060N...
# a050N000010XhDBQA0  [a060N00002XMfVcQAL, a060N00002Z7fjqQAB, a060N...
# a050N000010W5f8QAC  [a060N00002Z7fpZQAR, a060N00002Z7fpeQAB, a060N...
# a050N00000zZgFTQA0  [a060N00002XMfW7QAL, a060N00002XMfWNQA1, a060N...
# a050N00000zZg5LQAS  [a060N00002XMfWhQAL, a060N00002XMfWbQAL, a060N...
# a050N00000zbGGHQA2  [a060N00002XMfVdQAL, a060N00002XMfWNQA1, a060N...
# a050N00000zbGCDQA2  [a060N00002XMfZdQAL, a060N00002XMfU2QAL, a060N...
# a050N00000zZg63QAC  [a060N00002XMfaiQAD, a060N00002XMfXsQAL, a060N...
# a050N00000zZfz2QAC  [a060N00002XMfWNQA1, a060N00002XMfaTQAT, a060N...
# a050N00000zZfysQAC  [a060N00002XMfYIQA1, a060N00002XMfWoQAL, a060N...
# a050N00000zZg0HQAS  [a060N00002XMfc0QAD, a060N00002XMfdLQAT, a060N...
# a050N00000zZg0ZQAS  [a060N00002XMfaaQAD, a060N00002XMfUkQAL, a060N...
# a050N00000zZg44QAC  [a060N00002XMfYEQA1, a060N00002XMfW7QAL, a060N...
# a050N000010W5fIQAS  [a060N00002XMfaaQAD, a060N00002XMfTvQAL, a060N...
# a050N00000zZg0XQAS  [a060N00002XMfWNQA1, a060N00002XMfW9QAL, a060N...
# a050N00000zZg4XQAS  [a060N00002XMfX7QAL, a060N00002XMfXEQA1, a060N...
# a050N00000zZfyyQAC  [a060N00002XMfTnQAL, a060N00002XMfW7QAL, a060N...
# a050N00000zZg8lQAC  [a060N00002XMfXsQAL, a060N00002XMfW1QAL, a060N...
# a050N00000zZg4mQAC  [a060N00002XMfaiQAD, a060N00002XMfW9QAL, a060N...
# a050N00000zZg8DQAS  [a060N00002XMfXgQAL, a060N00002XMfW7QAL, a060N...
# a050N00000zZg4QQAS  [a060N00002XMfUbQAL, a060N00002XMfYYQA1, a060N...
# ...                                                               ...
# a050N000010YKzlQAG  [a060N00002XMfYQQA1, a060N00002Zo71YQAR, a060N...
# a050N00000zbES4QAM  [a060N00002XMfdsQAD, a060N00002XMfXgQAL, a060N...
# a050N00000zZfz5QAC  [a060N00002XMfZyQAL, a060N00002XMfU9QAL, a060N...
# a050N00000zZfz3QAC  [a060N00002XMfYEQA1, a060N00002XMfWNQA1, a060N...
# a050N00000zZg3YQAS  [a060N00002XMfaiQAD, a060N00002XMfW1QAL, a060N...
# a050N00000zZg65QAC  [a060N00002XMfaiQAD, a060N00002XMfaeQAD, a060N...
# a050N00000zZg4RQAS  [a060N00002XMfTnQAL, a060N00002XMfW7QAL, a060N...
# a050N000010X2aDQAS  [a060N00002XMfYLQA1, a060N00002XMfalQAD, a060N...
# a050N0000150ewBQAQ  [a060N00002grUCBQA2, a060N00002ZmIhDQAV, a060N...
# a050N00000zZg0YQAS  [a060N00002XMfWNQA1, a060N00002XMfZNQA1, a060N...
# a050N00000zZg4aQAC  [a060N00002XMfaiQAD, a060N00002XMfWNQA1, a060N...
# a050N000010X2ZeQAK  [a060N00002XMfa6QAD, a060N00002XMfXjQAL, a060N...
# a050N000010X9i6QAC  [a060N00002XMfTXQA1, a060N00002XMfVwQAL, a060N...
# a050N00000zbFdeQAE  [a060N00002XMfUeQAL, a060N00002XMfWDQA1, a060N...
# a050N000010YKy8QAG  [a060N00002XMfZBQA1, a060N00002Zq4QwQAJ, a060N...
# a050N00000zZg5SQAS  [a060N00002XMfdpQAD, a060N00002XMfVwQAL, a060N...
# a050N00000zZg58QAC  [a060N00002XMfXjQAL, a060N00002XMfW7QAL, a060N...
# a050N000010XhClQAK  [a060N00002XMfZBQA1, a060N00002XMfWAQA1, a060N...
# a050N00000zZg8XQAS  [a060N00002XMfaiQAD, a060N00002XMfW9QAL, a060N...
# a050N000010XNiZQAW  [a060N00002ZuTU3QAN, a060N00002Zd3qcQAB, a060N...
# a050N00000zZfyTQAS  [a060N00002XMfWNQA1, a060N00002XMfahQAD, a060N...
# a050N00000zZg4TQAS  [a060N00002XMfTnQAL, a060N00002XMfW7QAL, a060N...
# a050N00000zZg64QAC  [a060N00002XMfaiQAD, a060N00002XMfW9QAL, a060N...
# a050N00000zZfzeQAC  [a060N00002XMfWNQA1, a060N00002XMfW7QAL, a060N...
# a050N00000zZg4SQAS  [a060N00002XMfXsQAL, a060N00002XMfVVQA1, a060N...
# a050N00000zbESJQA2  [a060N00002XMfdsQAD, a060N00002Z7gBYQAZ, a060N...
# a050N00000zZg8WQAS  [a060N00002XMfWgQAL, a060N00002XMfYOQA1, a060N...
# a050N000013v74gQAA  [a060N00002fgI5eQAE, a060N00002Zo4t5QAB, a060N...
# a050N000010XhCMQA0  [a060N00002XMfVmQAL, a060N00002XMfUvQAL, a060N...
# a050N00000zbFdjQAE  [a060N00002XMfVcQAL, a060N00002Z7fjqQAB, a060N...
#
#                     offered_count
# meal_id
# a050N00000zZg5KQAS              1
# a050N00000zZfzCQAS              1
# a050N00000zZfyUQAS              6
# a050N000010W5ezQAC              4
# a050N00000zZg8NQAS              3
# a050N00000zZg5EQAS              5
# a050N00000zZgH3QAK              5
# a050N00000zZg8AQAS              9
# a050N000010W5f9QAC              2
# a050N00000za4nqQAA              7
# a050N000010XhDBQA0              3
# a050N000010W5f8QAC              2
# a050N00000zZgFTQA0              2
# a050N00000zZg5LQAS              4
# a050N00000zbGGHQA2              1
# a050N00000zbGCDQA2              3
# a050N00000zZg63QAC              9
# a050N00000zZfz2QAC              4
# a050N00000zZfysQAC              2
# a050N00000zZg0HQAS              2
# a050N00000zZg0ZQAS              7
# a050N00000zZg44QAC              1
# a050N000010W5fIQAS              1
# a050N00000zZg0XQAS              7
# a050N00000zZg4XQAS              6
# a050N00000zZfyyQAC              4
# a050N00000zZg8lQAC              7
# a050N00000zZg4mQAC              2
# a050N00000zZg8DQAS              2
# a050N00000zZg4QQAS              4
# ...                           ...
# a050N000010YKzlQAG              1
# a050N00000zbES4QAM              7
# a050N00000zZfz5QAC              4
# a050N00000zZfz3QAC              4
# a050N00000zZg3YQAS              1
# a050N00000zZg65QAC             10
# a050N00000zZg4RQAS              5
# a050N000010X2aDQAS              1
# a050N0000150ewBQAQ              1
# a050N00000zZg0YQAS              7
# a050N00000zZg4aQAC              2
# a050N000010X2ZeQAK              1
# a050N000010X9i6QAC              2
# a050N00000zbFdeQAE              4
# a050N000010YKy8QAG              2
# a050N00000zZg5SQAS              1
# a050N00000zZg58QAC              5
# a050N000010XhClQAK              3
# a050N00000zZg8XQAS              7
# a050N000010XNiZQAW              1
# a050N00000zZfyTQAS              6
# a050N00000zZg4TQAS              2
# a050N00000zZg64QAC             10
# a050N00000zZfzeQAC              2
# a050N00000zZg4SQAS              3
# a050N00000zbESJQA2              7
# a050N00000zZg8WQAS              7
# a050N000013v74gQAA              1
# a050N000010XhCMQA0              3
# a050N00000zbFdjQAE              3
#
# [90 rows x 3 columns]

# %%
## Function gives list of ingredients user as has seen (remove never seen ingrds)
def seen_ingredients(user):
    rows, cols = user.X.shape
    keeps = []
    for i in range(cols):
        if (user.X[:,i] == 1).sum() != 0:
            keeps.append(i)
            
    return keeps

## Gets cross validated accuracy and AUC for different models
def cross_val(X_train, y_train, func):

    mse = -sum(cross_val_score(func, X_train, y_train, cv=4, scoring='neg_mean_squared_error'))/4
    func_name = str(func.__class__.__name__)
    print("{0:27} Train CV | Mean Square Error: {1:5.4}".format(func_name, mse))
    return mse

# %%
keeps = seen_ingredients(u)
X = u.X[:,keeps]
y = u.y

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)
rf_model = RandomForestRegressor(max_depth=30, n_estimators=20)
cross_val(X_train, y_train, rf_model)**.5
# Out:
# RandomForestRegressor       Train CV | Mean Square Error: 0.1316
# 0.3627079659020997

# %%
u.y
# Out:
# array([1.        , 1.        , 0.33333333, 0.25      , 0.66666667,
#        0.6       , 0.6       , 0.88888889, 0.5       , 1.        ,
#        0.33333333, 0.5       , 0.5       , 0.5       , 1.        ,
#        0.33333333, 0.55555556, 0.25      , 1.        , 1.        ,
#        0.28571429, 1.        , 1.        , 0.42857143, 0.5       ,
#        0.5       , 0.28571429, 1.        , 0.5       , 0.25      ,
#        1.        , 0.5       , 0.5       , 0.33333333, 0.14285714,
#        0.5       , 0.25      , 0.66666667, 1.        , 0.5       ,
#        0.09090909, 0.28571429, 0.33333333, 1.        , 1.        ,
#        0.5       , 0.33333333, 0.5       , 0.6       , 1.        ,
#        0.5       , 0.42857143, 0.28571429, 1.        , 1.        ,
#        0.14285714, 1.        , 0.2       , 0.14285714, 1.        ,
#        1.        , 0.14285714, 0.5       , 0.25      , 1.        ,
#        0.3       , 0.4       , 1.        , 1.        , 0.28571429,
#        1.        , 1.        , 1.        , 0.25      , 0.5       ,
#        1.        , 0.4       , 0.33333333, 0.28571429, 1.        ,
#        0.5       , 0.5       , 0.2       , 0.5       , 0.33333333,
#        0.42857143, 0.28571429, 1.        , 0.33333333, 0.33333333])
