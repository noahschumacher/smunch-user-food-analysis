# %%
import pandas as pd
import numpy as np
import pickle

import matplotlib.pyplot as plt

import os
os.chdir('/Users/nschumacher/docs/galvanize/smunch-user-food-analysis')

# %matplotlib inline  
# %config InlineBackend.figure_format='retina'

# %%
user_objs = pickle.load(open('order_prediction/user_objects_dict.p', 'rb'))

# %%
## Get avg percent improvement
improvs = []
for key in user_objs.keys():
    improvs.append(user_objs[key].precent_improvement)

# %%
## Avg percent improvement
np.mean(improvs)
# Out:
# 1.623440730314409

# %%
mes = []
for key in user_objs.keys():
    u = user_objs[key]
    me = (np.round(u.mse**.5, 3), np.round(u.avg_mse**.5, 3), np.round(u.base_mse**.5, 3))
    mes.append(me)
    
np_mes = np.vstack(mes)

plt.figure(figsize=(17,8))

xs = np.arange(len(mes))
plt.plot(xs, np_mes[:,0], c='r', linestyle='-', label='Random Forrest Model')
plt.plot(xs, np_mes[:,1], c='g', linestyle='-', label='Avg User Var Model')
plt.plot(xs, np_mes[:,2], c='b', linestyle='-', label='Base Model')

means = np.mean(np_mes, axis=0)
plt.hlines(means[0], 0, len(xs), color='r', linestyle='--', label='RF mean: {0:1.3f}'.format(means[0]))
plt.hlines(means[1], 0, len(xs), color='g', linestyle='--', label='Avg mean: {0:1.3f}'.format(means[1]))
plt.hlines(means[2], 0, len(xs), color='b', linestyle='--', label='Base mean: {0:1.3f}'.format(means[2]))

plt.title("Mean Error (0, 1) vs User")
plt.xlabel("User")
plt.ylabel("Mean Error")
plt.legend()
plt.minorticks_on()
plt.grid()
plt.show()

# %%
for i, key in enumerate(user_objs.keys()):
    u = user_objs[key]
    if (i>=70) and (i<95):
        print(i)
        print(u.y)
        print(np.mean(u.y))
# Out:
# 70
# [0.48  0.098 0.889 0.235 0.706 0.552 0.8   0.889 0.552 0.706 0.235 0.966
#  0.8   0.889 0.121 0.8   0.8   0.727 0.121 0.8   0.8   0.8   0.444 0.941
#  0.235 0.471 0.235 0.889 0.706 0.058 0.754 0.19  0.923 0.208 0.235 0.952
#  0.615 0.471 0.889 0.96  0.471 0.471 0.444 0.444 0.16  0.8   0.16  0.308
#  0.235 0.706 0.32  0.64  0.444 0.444 0.97  0.706 0.235 0.889 0.727 0.121
#  0.121 0.952 0.923 0.8   0.889 0.889 0.308 0.615 0.8   0.471 0.471 0.923
#  0.889 0.8   0.8   0.308 0.615 0.8   0.444 0.444 0.8   0.444 0.235 0.444
#  0.444 0.8   0.8   0.8   0.889]
# 0.5905056179775281
# 71
# [0.649 0.108 0.432 0.432 0.377 0.49  0.8   0.235 0.471 0.242 0.235 0.089
#  0.178 0.952 0.952 0.055 0.8   0.308 0.444 0.131 0.8   0.787 0.8   0.8
#  0.889 0.8   0.308 0.615 0.16  0.8   0.414 0.16  0.16  0.8   0.898 0.082
#  0.364 0.293 0.96  0.444 0.444 0.444 0.444 0.16  0.16  0.8   0.308 0.97
#  0.941 0.485 0.485 0.889 0.281 0.281 0.242 0.706 0.8   0.8   0.615 0.8
# ...
