# %%
## Initialization and imports
import pandas as pd 
import numpy as np 

## Changing directory to top folder (All programs run from top)
import os
os.chdir('/Users/nschumacher/docs/galvanize/smunch-user-food-analysis')

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform
from scipy.cluster.hierarchy import dendrogram, linkage

from matplotlib import pyplot as plt
# %matplotlib inline  
# %config InlineBackend.figure_format='retina'

## Set random seed
np.random.seed(seed=14)

# %%
## Read in pickle data
ing_freq = pd.read_pickle("pickle/user_f_df_tot.p")
ing_freq.sample(3)
# Out:
#       tahini  paprika (red and green)  pork salsiccia  organic red quinoa  \
# 4336     0.0                      0.0             0.0                 0.0
# 490      0.0                      0.0             0.0                 0.0
# 4385     0.0                      0.0             0.0                 0.0
#
#       caramelized sugar syrup  dry white wine  red curry powder  shiso leaves  \
# 4336                      0.0             0.0               0.0           0.0
# 490                       0.0             0.0               0.0           0.0
# 4385                      0.0             0.0               0.0           0.0
#
#       serrano ham  bulls blood lettuce         ...          mushrooms  \
# 4336          0.0                  0.0         ...              0.100
# 490           0.0                  0.0         ...              0.112
# 4385          0.0                  0.0         ...              0.000
#
#       bell peppers  egg noodles  radish  capsicum  turmeric   dill  \
# 4336         0.100          0.0   0.000       0.0       0.0  0.200
# 490          0.112          0.0   0.056       0.0       0.0  0.056
# 4385         0.222          0.0   0.111       0.0       0.0  0.222
#
#       parboiled rice  soya nuggets (soya flour)             cust_id
# 4336             0.1                        0.0  0030N00002Prid4QAB
# 490              0.0                        0.0  0030N00002LQpGaQAL
# 4385             0.0                        0.0  0030N00002QQPT3QAP
#
# [3 rows x 987 columns]

# %%
ing_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7149 entries, 0 to 7148
# Columns: 987 entries, tahini to cust_id
# dtypes: float64(986), object(1)
# memory usage: 53.9+ MB

# %%
## Need to scale the features for clustering (distance metric)
def scale_df(df):
    for col in df.columns:
        if col != 'cust_id':
            df[col] = (df[col] - df[col].mean())/df[col].std()
    return df
        
ing_freq = scale_df(ing_freq)

# %%
# ## Exploring which ingredients are the most and least used
# cols = ing_freq.columns
# ing_means = ing_freq[cols].mean()  ## The variance in frequency would indicate strong preferences on ingredient
# top_ings = ing_means.sort_values().index.values[:]  ## Choosing the x ingredients with the most variance

top_ing_f = ing_freq.copy()
top_ing_f.head(4)
# Out:
#      tahini  paprika (red and green)  pork salsiccia  organic red quinoa  \
# 0  0.439762                -0.119283        -0.04513           -0.054307
# 1 -0.345840                -0.119283        -0.04513           -0.054307
# 2 -0.476773                -0.119283        -0.04513           -0.054307
# 3 -0.476773                -0.119283        -0.04513           -0.054307
#
#    caramelized sugar syrup  dry white wine  red curry powder  shiso leaves  \
# 0                -0.210455       -0.033622          -0.10384     -0.290243
# 1                -0.210455       -0.033622          -0.10384     -0.290243
# 2                -0.210455       -0.033622          -0.10384     -0.290243
# 3                -0.210455       -0.033622          -0.10384     -0.290243
#
#    serrano ham  bulls blood lettuce         ...          mushrooms  \
# 0    -0.116061            -0.141858         ...           2.893389
# 1    -0.116061            -0.141858         ...          -0.390485
# 2    -0.116061            -0.141858         ...          -0.937798
# 3    -0.116061            -0.141858         ...           0.094633
#
#    bell peppers  egg noodles    radish  capsicum  turmeric      dill  \
# 0     -0.518556    -0.255404  0.851682 -0.033952 -0.062689  1.001815
# 1      0.308259    -0.255404  0.091406 -0.033952 -0.062689 -0.472417
# 2      1.567273    -0.255404 -0.922297 -0.033952 -0.062689 -0.874480
# 3     -0.518556    -0.255404  0.033809 -0.033952 -0.062689  1.148020
#
#    parboiled rice  soya nuggets (soya flour)             cust_id
# 0       -0.133621                  -0.082007  0030N00002I6CDNQA3
# 1        1.796900                  -0.082007  0030N00002LQoyvQAD
# 2       -0.133621                  -0.082007  0030N00002LQp1pQAD
# 3       -0.133621                  -0.082007  0030N00002LQp3lQAD
#
# [4 rows x 987 columns]

# %%
convert = pd.read_csv('data/ing_to_cat.csv')
convert = convert.dropna()

new_df = pd.DataFrame(columns=convert.category.unique())

d = pd.Series(convert.category.values, convert.ing.values).to_dict()

for col in top_ing_f.columns:
    if col in d.keys():
        print("In")
        new_col = d[col]
        vals = top_ing_f[col].values
        
        if len(new_df[new_col].values) < 1:
            print("first")
            new_df[new_col] = vals
        else:
            vs = new_df[new_col].values
            new_df[new_col] = vs+vals
            

new_df
# Out:
# first
#       savory sauce spice meat  veg sweet sauce  alc herb pork grain sauce  \
# 0         1.690664   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 1        -0.707124   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 2        -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 3        -0.381505   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 4        -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 5         3.357763   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 6        -0.203342   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7         0.826089   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 8         2.231980   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 9         0.451399   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 10       -1.038376   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 11       -0.881700   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 12        0.039265   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 13       -0.493179   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 14        4.933425   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 15       -0.072735   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 16        0.863139   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 17        0.039265   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 18        3.736893   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 19        0.697840   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 20       -1.309674   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 21        3.659678   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 22       -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 23        0.698658   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 24        0.863028   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 25       -1.341568   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 26       -0.653768   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 27       -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 28        3.848959   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 29        6.256070   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# ...            ...   ...  ...  ...         ...  ...  ...  ...   ...   ...
# 7119     -0.448043   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7120     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7121      2.775157   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7122     -0.666143   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7123      3.347353   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7124     -0.947971   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7125     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7126     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7127     20.110900   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7128     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7129     -1.198294   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7130     -0.369129   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7131     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7132     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7133     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7134     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7135     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7136     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7137     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7138      3.633808   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7139     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7140     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7141     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7142     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7143     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7144     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7145     -0.733716   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7146     -2.435853   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7147      5.227679   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
# 7148     12.442963   NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN   NaN
#
#         ...    sour wheat octopus falafel noodle  prk paste df cream salmon  \
# 0       ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 1       ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 2       ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 3       ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 4       ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 5       ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 6       ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7       ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 8       ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 9       ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 10      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 11      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 12      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 13      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 14      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 15      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 16      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 17      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 18      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 19      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 20      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 21      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 22      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 23      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 24      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 25      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 26      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 27      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 28      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 29      ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# ...     ...     ...   ...     ...     ...    ...  ...   ...      ...    ...
# 7119    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7120    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7121    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7122    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7123    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7124    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7125    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7126    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7127    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7128    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7129    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7130    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7131    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7132    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7133    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7134    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7135    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7136    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7137    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7138    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7139    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7140    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7141    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7142    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7143    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7144    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7145    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7146    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7147    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
# 7148    ...     NaN   NaN     NaN     NaN    NaN  NaN   NaN      NaN    NaN
#
#      df cheese
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# ...        ...
# 7119       NaN
# 7120       NaN
# 7121       NaN
# 7122       NaN
# 7123       NaN
# 7124       NaN
# 7125       NaN
# 7126       NaN
# 7127       NaN
# 7128       NaN
# 7129       NaN
# 7130       NaN
# 7131       NaN
# 7132       NaN
# 7133       NaN
# 7134       NaN
# 7135       NaN
# 7136       NaN
# 7137       NaN
# 7138       NaN
# 7139       NaN
# 7140       NaN
# 7141       NaN
# 7142       NaN
# 7143       NaN
# 7144       NaN
# 7145       NaN
# 7146       NaN
# 7147       NaN
# 7148       NaN
#
# [7149 rows x 90 columns]

# %% [markdown]
# #### Kmeans clustering

# %%
## Assinging the features to X
custs = top_ing_f.cust_id.values
top_ing_f.drop('cust_id', axis=1, inplace=True)
X = top_ing_f.values

# %%
## Kmeans object with cluster rows are clusters and cols are feature coords
kmeans = KMeans(n_clusters=3, random_state=0, n_jobs=-1).fit(X)

# %%
## Print the top words from each topic
def print_top_ingredients(centroid_data, vocab, n_top_words):
    
    ## Getting sorted indexs of feature importance
    sortedX = np.argsort(centroid_data, axis = 1)
    
    ## Printing top words in each 'topic'
    t = {}
    for i, row in enumerate(sortedX[:, -1:-n_top_words-1:-1]):
        t[i] = [vocab[i] for i in row]
        #print("Topic", i,':', ', '.join([vocab[i] for i in row]))
    
    return pd.DataFrame(t)

# %%
print_top_ingredients(kmeans.cluster_centers_, top_ing_f.columns.values, 40)
# Out:
#                                          0                      1  \
# 0                                   sesame           rapeseed oil
# 1                             bean sprouts                  onion
# 2                          romaine lettuce                  cream
# 3                      mixed green lettuce                   dill
# 4                             shiso leaves                 garlic
# 5                                   radish                  sugar
# 6                              yukari salt        vegetable stock
# 7                             shiso flakes            breadcrumbs
# 8                             sweet potato           bell peppers
# 9                               sesame oil                 butter
# 10                               olive oil         red bellpepper
# 11                  baguette bread (flour)          potato starch
# 12                               coriander                  salad
# 13                          thai basilikum            minced beef
# 14                         pickled veggies                   peas
# 15                                 edamame               rosemary
# 16                          cheddar cheese              cranberry
# 17                               raw mango     white basmati rice
# 18  garlic bread (flour / garlic / butter)                vinegar
# 19                             green onion                 manioc
# 20                                    salt             mayonnaise
# 21               arabic pita bread (flour)            cauliflower
# 22                               soy sauce          creme fraiche
# 23                                   chili           tomato paste
# 24                              rice paper                parsley
# 25                                soyabean                  thyme
# 26                      shiitake mushrooms                 chives
# 27                             vinaigrette  paprika powder (mild)
# 28                                 lentils             sweet peas
# 29                      red cabbage kimchi                majoram
# 30                                    mint               eggplant
# 31                                    date                 rucola
# 32                           sunflower oil          peanut butter
# 33                                  rocket           goji berries
# 34                       teriyaki marinade            minced pork
# 35                             fried onion               pak choi
# 36                       bulghur tabbouleh            red mangold
# 37                          wakame seaweed         sweet potatoes
# 38      glass noodle (sweet potato starch)                  flour
# 39                  jalapeno chilli pepper                  basil
#
#                       2
# 0                yogurt
# 1              chickpea
# 2         indian spices
# 3            lemonjuice
# 4               carrots
# 5         chilli powder
# 6                 curry
# 7            pita bread
# 8           ground beef
# 9             guacamole
# 10                chips
# 11               chilli
# 12           thai basil
# 13           chilipesto
# 14         hoisin sauce
# 15    mixed green salad
# 16        fried noodles
# 17     red-wine-vinegar
# 18              cheddar
# 19         mixed grains
# 20                dates
# 21               nachos
# 22        beef ranchera
# 23        wrap tortilla
# 24              curcuma
# 25           mango pulp
# 26     teriyaki chicken
# 27                  soy
# 28                  fig
# 29          ground pork
# 30              noodles
# 31             cardamom
# 32          soy sprouts
# 33                  oil
# 34       chickpea salad
# 35  indian cream cheese
# 36       fruit cocktail
# 37          salsa verde
# 38             coleslaw
# 39          chilli-mayo

# %%
## Scoring Kmeans

## Running kmeans
def run_kmeans(data, n):
    kmeans = KMeans(n_clusters=n, random_state=0, n_jobs=-1).fit(data)
    
    return silhouette_score(data, kmeans.labels_)


## Finds the opitmal k value
def find_k(data, k):
    sil_scores = []
    for i in range(2, k):
        scores = (run_kmeans(data, i))
        sil_scores.append(scores)
        
    return sil_scores 

sils = find_k(X, 10)

plt.title("Silhouette Score vs Number of Clusters")
plt.ylabel("Silhouette Score")
plt.xlabel("Number of Clusters")
plt.grid()
plt.plot(range(2, len(sils)+2), sils)

# %% [markdown]
# #### Hierarchical Clustering

# %%
def high_clustering(data, sample_size, dist_measure='cosine', plot='yes'):

    ## Selecting n random customers to look at
    trimmed_data = np.random.choice(range(data.shape[0]), sample_size)
    X = data.iloc[trimmed_data]

    ## Get vector distances (can be different measures) and squaring array
    Y = pdist(X, 'cosine')
    squareY = squareform(Y)

    ## Creates the linkage matrix with 
    return linkage(squareY, 'average')

## Plot the dendrogram
def plot_dendro(Z, labels, orient='top', thresh=None, font_s=20):
    fig = plt.figure(figsize=(25, 40))
    dn = dendrogram(Z)

    section = np.array(dn["ivl"]).astype(int)

    dn = dendrogram(Z, 
                    orientation=orient,
                    color_threshold=thresh,
                    labels=labels,
                    leaf_font_size=font_s)
    plt.ylabel('Threshold')
    plt.xlabel('User')
    plt.title('User Ingredient Frequency Dendrogram')
    plt.show()

# %%
linkage1 = high_clustering(top_ing_f, 100)
plot_dendro(linkage1, top_ing_f.columns, orient='right', thresh=1.80, font_s=12)
# Out:
# /Users/nschumacher/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   if sys.path[0] == '':
